# %% [markdown]
# #  📘 **EDA (Exploratory Data Analysis)**
# ### **📚 Introducció a Machine Learning**
# ##### 🗂️ M0572 Sistemes d'aprenentatge automàtic
# ###### 👤 *Robert Ventura Vall-llovera*
# ---
# ## ✏️ **Exercici - EDA Iris Dataset**
#
# Aquest notebook és un **exercici pràctic** per fer Anàlisis Exploratori de Dades (EDA) sobre el famós **dataset Iris**, un conjunt de dades molt utilitzat en Machine Learning.
#
# <img align="center" src="data:image/png;base64,..."/>
#
# ### 🚀 Objectius
# - Conèixer el dataset (dimensions, tipus de dades, valors nuls)
# - Analitzar distribucions univariades i bivariades
# - Detectar outliers i anomalies
# - Formular hipòtesis i contrastar-les amb visualitzacions i estadístiques
# - Proposar transformacions i noves característiques
#
# ---

# %% [markdown]
# ## 1. Importa les llibreries necessàries

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 2. Carrega el dataset Iris
#
# El dataset Iris està inclòs a `sklearn` i conté informació de 150 mostres de flors d’iris
# amb 4 característiques: longitud i amplada del sèpal, longitud i amplada del pètal,
# a més de la seva espècie.

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 3. Exploració inicial del dataset

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 4. Valors nuls i duplicats

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 5. Distribucions de variables numèriques

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 6. Boxplots i detecció d'outliers

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 7. Matriu de correlació

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 8. Pairplot de variables

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 9. Anàlisi per categories (espècies)

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 10. Creació de noves característiques

# %%
# Escriu aquí el teu codi

# %% [markdown]
# ## 11. Conclusions
#
# Redacta aquí un breu resum de les teves observacions sobre el dataset.
#
# ---
#
# ## 📝 Reptes addicionals
# 1. Representa gràficament la distribució de cada característica per espècie.
# 2. Comprova si hi ha correlació entre longitud i amplada dels pètals.
# 3. Crea una nova característica derivada de les existents (ex. ràtio pètal/sèpal).
# 4. Escriu un breu resum de les teves conclusions sobre el dataset.
