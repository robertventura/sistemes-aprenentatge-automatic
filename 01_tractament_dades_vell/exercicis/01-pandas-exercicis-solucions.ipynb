# %% [markdown]
# # Exercicis - Pandas  <img align="right"  width="185" height="75"  src="../img/pandas-logo.png" alt="pandas_logo"/>
#
# Exercicis relacionats en lla llibreria [Pandas](https://pandas.pydata.org/) per el tractament de dades

# %% [markdown]
# ## Exercici 1
# Crea un DataFrame anomenat `fruites` seguint la següent estructura
#
# |   | Pomes | Peres |
# |---|-------|-------|
# | 0 | 21    | 22    |

# %%
import pandas as pd

fruites = {'Pomes':[21],
        'Peres':[22]}

pd.DataFrame(fruites)
# Out:
#    Pomes  Peres
# 0     21     22

# %% [markdown]
# ## Exercici 2
# Crea un DataFrame anomenat `vendes_fruites` seguin la següent estructura
#
# |      | Pomes | Peres |
# |------|-------|-------|
# | 2017 | 21    | 22    |
# | 2018 | 42    | 15    |

# %%
vendes_fruites = pd.DataFrame({'Pomes':[21,42],'Peres':[22,15]},
          index=['2017','2018'])

pd.DataFrame(vendes_fruites)
# Out:
#       Pomes  Peres
# 2017     21     22
# 2018     42     15

# %% [markdown]
# ## Exercici 3
#
# Crea una variable `ingredients` mitjançant Series seguin la següent estructura
#
# ```
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
# ```

# %%
ingredients= pd.Series(['4 cups','1 cup', '2 large', '1 can'],
                      index=['Flour','Milk','Eggs','Spam'], name='dinner')

pd.Series(ingredients)
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: dinner, dtype: object

# %% [markdown]
# # Exercici 4
# Llegeix el següent conjunt de dades CSV de valoracions de vins dins d'un DataFrame anomenat `reviews`
# Origen de dades: dataset/wine-reviews/winemag-data_first150k.csv

# %%
reviews = pd.read_csv('dataset/wine-reviews/winemag-data_first150k.csv')
reviews.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %% [markdown]
# # Exercici 5
# Carrega la variable animals executant el següent tall de codi i guarda el DataFrame a disk en un fitxer CSV

# %%
import pandas as pd

animals = pd.DataFrame({'Vaques': [12, 20], 'Cabres': [22, 19]}, index=['Any 1', 'Any 2'])

## Guardem el DataFrame a disk
animals.to_csv('Animals.csv')

# %% [markdown]
# # Exercici 6
# Del dataset `dataset/wine-reviews/winemag-data_first150k.csv`
#
# Selecciona la columna `description` de les valoracions i guard-ho a la variable `desc`

# %%
reviews = pd.read_csv('dataset/wine-reviews/winemag-data_first150k.csv', index_col=False)

reviews.description
# Out:
# 0         This tremendous 100% varietal wine hails from ...
# 1         Ripe aromas of fig, blackberry and cassis are ...
# 2         Mac Watson honors the memory of a wine once ma...
# 3         This spent 20 months in 30% new French oak, an...
# 4         This is the top wine from La Bégude, named aft...
#                                 ...
# 150925    Many people feel Fiano represents southern Ita...
# 150926    Offers an intriguing nose with ginger, lime an...
# 150927    This classic example comes from a cru vineyard...
# 150928    A perfect salmon shade, with scents of peaches...
# 150929    More Pinot Grigios should taste like this. A r...
# Name: description, Length: 150930, dtype: object

# %% [markdown]
# # Exercici 7
# Seleciona el primer valor de la columna `description` de les valoracions. Assigna el resultat a la variable `primera_descripcio`

# %%
reviews.loc[0,'description']

desc.iloc[0:1]     

descriptions= pd.read_csv('dataset/wine-reviews/winemag-data_first150k.csv', usecols=['description'])
descriptions.head(1)

reviews.description[0]

# %% [markdown]
# # Exercici 8
# Selecciona la primera fila / primer registre de les valoracions, assigna-ho a la variable `primera_fila`

# %%
reviews.iloc[0,:]
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
# designation                                    Martha's Vineyard
# points                                                        96
# price                                                      235.0
# province                                              California
# region_1                                             Napa Valley
# region_2                                                    Napa
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, dtype: object

# %% [markdown]
# # Exercici 9
# Selecciona els 10 primers valors de la columna `description` de les valoracions, assigna el resultat a la variable `primeres_descripcions`.

# %%
reviews.iloc[:10].description
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# 5    Deep, dense and pure from the opening bell, th...
# 6    Slightly gritty black-fruit aromas include a s...
# 7    Lush cedary black-fruit aromas are luxe and of...
# 8    This re-named vineyard was formerly bottled as...
# 9    The producer sources from two blocks of the vi...
# Name: description, dtype: object

# %% [markdown]
# # Exercici 10
# Selecciona els registres dels següents índexs: 1, 2, 3, 5, and 8, assigna el resultats a la variable sample_reviews.
#
# ![](https://i.imgur.com/sHZvI1O.png)

# %%
reviews.iloc[[1,2,3,5,8]]
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# 2      Knights Valley             Sonoma  Sauvignon Blanc
# 3   Willamette Valley  Willamette Valley       Pinot Noir
# 5                Toro                NaN    Tinta de Toro
# 8  Chehalem Mountains  Willamette Valley       Pinot Noir
#
#                     winery
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 5                Numanthia
# 8                Bergström

# %% [markdown]
# # Exercici 11
# Crea una variable `df` que contingui les columnes `country, province, region_1, and region_2` dels registres amb índexs 0, 1, 10, and 100. Hauria de ser un resultat com aquest:
#
# ![](https://i.imgur.com/FUCGiKP.png)

# %%
reviews.iloc[[0,1,10,100],:].loc[:,['country', 'province', 'region_1', 'region_2']]

reviews.loc[[0,1,10,100],['country', 'province', 'region_1', 'region_2']]

#reviews.iloc[[0,1,10,100],:].loc[[1,8],['country','province','region_1','region_2']]
# Out:
# (150930, 10)

# %% [markdown]
# # Exercici 12
# Crea una variable `df` que contingui les columnes `country` i `variety` dels primers 100 registres.
#
# Utilitza `loc` o `iloc`. Quan treballeu en la resposta a aquesta pregunta i a les diverses que segueixen, manteniu el següent "gotcha" descrit al tutorial:
#
# > Compte amb l'ús de `iloc`. En aquest cas, `df.iloc[0:100]` retornarà 100 entrades, mentre que `df.loc[0:100]` en retornarà 101! Per obtenir 100 elements amb `loc`, haureu d'anar un més avall i demanar `df.loc[0:99]`.

# %%
reviews.iloc[0:100].loc[:,['country', 'variety']]

reviews.iloc[0:100,[0,8]]
# Out:
#    country               variety
# 0       US    Cabernet Sauvignon
# 1    Spain         Tinta de Toro
# 2       US       Sauvignon Blanc
# 3       US            Pinot Noir
# 4   France    Provence red blend
# ..     ...                   ...
# 95  France         Malbec-Merlot
# 96      US            Chardonnay
# 97      US    Cabernet Sauvignon
# 98  France         Merlot-Malbec
# 99  France  Ugni Blanc-Colombard
#
# [100 rows x 2 columns]

# %% [markdown]
# # Exercici 13
# Crea un DataFrame anomenat vins_italians que contingui els vins italians

# %%
reviews[reviews.country=='Italy']

reviews[reviews.country.isin(["Italy"])]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                           designation  points  price            province  \
# 0                   Martha's Vineyard      96  235.0          California
# 2       Special Selected Late Harvest      96   90.0          California
# 3                             Reserve      96   65.0              Oregon
# 8                              Silice      95   65.0              Oregon
# 9                Gap's Crown Vineyard      95   60.0          California
# ...                               ...     ...    ...                 ...
# 150920                   Brut Riserva      91   19.0  Northeastern Italy
# 150922                      Superiore      91    NaN  Northeastern Italy
# 150925                            NaN      91   20.0      Southern Italy
# 150927                  Terre di Dora      91   20.0      Southern Italy
# 150929                            NaN      90   15.0  Northeastern Italy
#
#                           region_1           region_2             variety  \
# 0                      Napa Valley               Napa  Cabernet Sauvignon
# 2                   Knights Valley             Sonoma     Sauvignon Blanc
# 3                Willamette Valley  Willamette Valley          Pinot Noir
# 8               Chehalem Mountains  Willamette Valley          Pinot Noir
# 9                     Sonoma Coast             Sonoma          Pinot Noir
# ...                            ...                ...                 ...
# 150920                      Trento                NaN     Champagne Blend
# 150922  Colli Orientali del Friuli                NaN               Tocai
# 150925           Fiano di Avellino                NaN         White Blend
# 150927           Fiano di Avellino                NaN         White Blend
# 150929                  Alto Adige                NaN        Pinot Grigio
#
#                        winery
# 0                       Heitz
# 2                    Macauley
# 3                       Ponzi
# 8                   Bergström
# 9                   Blue Farm
# ...                       ...
# 150920                Letrari
# 150922      Ronchi di Manzano
# 150925  Feudi di San Gregorio
# 150927              Terredora
# 150929          Alois Lageder
#
# [85875 rows x 10 columns]

# %% [markdown]
# # Exercici 14
# Crea un DataFrame `top_oceania_wines` que contingui totes les valoracions de com a mínim amb un 95 de puntuació dels vins d'Australia (Australia) i Nova Zelanda (New Zeeland).

# %%
reviews[(reviews.country.isin(["Australia","New Zeeland"])) & (reviews.points >= 95)]
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# 2148                      The Factor      98  125.0  South Australia
# 2458                       The Peake      96  150.0  South Australia
# 3033                         Bin 707      95  500.0  South Australia
# 3044        Mount Edelstone Vineyard      95  200.0  South Australia
# 3047                             One      95   95.0  South Australia
# ...                              ...     ...    ...              ...
# 122779  The Standish Single Vineyard      96  135.0  South Australia
# 127614                 Hill of Grace      95  625.0  South Australia
# 137383                      Astralis      95  225.0  South Australia
# 150562                        Grange      96  185.0  South Australia
# 150563                           RWT      95   70.0  South Australia
#
#                region_1 region_2             variety           winery
# 2148     Barossa Valley      NaN              Shiraz         Torbreck
# 2458       McLaren Vale      NaN     Cabernet-Shiraz     Hickinbotham
# 3033    South Australia      NaN  Cabernet Sauvignon         Penfolds
# 3044        Eden Valley      NaN              Shiraz         Henschke
# 3047    Langhorne Creek      NaN           Red Blend        Heartland
# ...                 ...      ...                 ...              ...
# 122779   Barossa Valley      NaN              Shiraz         Standish
# 127614      Eden Valley      NaN              Shiraz         Henschke
# 137383        Clarendon      NaN               Syrah  Clarendon Hills
# 150562  South Australia      NaN              Shiraz         Penfolds
# 150563   Barossa Valley      NaN              Shiraz         Penfolds
#
# [82 rows x 10 columns]

# %% [markdown]
# ---------------------
#
# A partir d'aquest exercici utilitza el dataset `dataset/wine-reviews/winemag-data-130k-v2.csv`
#
# ---------------------

# %%
import pandas as pd

reviews = pd.read_csv('dataset/wine-reviews/winemag-data-130k-v2.csv', index_col=False)
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# # Exercici 15
#
# Crea una "Sèrie" a on líndex sigui el compte de twitter i els valors quantes ressenyes ha escrit.

# %%
reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: taster_twitter_handle, dtype: int64

# %%
reviews.groupby('taster_twitter_handle').taster_twitter_handle.size()
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: taster_twitter_handle, dtype: int64

# %% [markdown]
# # Exercici 16
#
# Quin és el millor vi que puc comprar per una quantitat determinada de diners?
#
# Crea una sèrie a on l'índex sigui els preus del vi i els valors siguin el nombre màxim de punts que es va donar en un vi per aquest preu.
#
# Ordena els valors per preu, de manera ascendent (de manera que 4,0 dòlars estiguin a la part superior i 3300,0 dòlars a la part inferior).

# %%
reviews.groupby(['price']).points.max().sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %% [markdown]
# # Exercici 17
#
# Quins són els preus mínims i màxims per a cada varietat de vi?
#
# De cada varietat de vi volem saber el preu mínim i màxim .

# %%
reviews.groupby("variety").price.agg([min,max])
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %% [markdown]
# # Exercici 18
#
# Quines són les varietats de vi més cares?
#
# Guarda en una variable `ordre_varietats` que contingui una còpia de les dades de la pregunta anterior on les varietats s'ordenen en ordre descendent en funció del preu mínim i després del preu màxim.

# %%
ordre_varietats = reviews.groupby("variety").price.agg([min,max])
ordre_varietats.sort_values(['min','max'],ascending=[False,False]).head(20)
# Out:
#                               min    max
# variety
# Ramisco                     495.0  495.0
# Terrantez                   236.0  236.0
# Francisa                    160.0  160.0
# Rosenmuskateller            150.0  150.0
# Tinta Negra Mole            112.0  112.0
# Pignolo                      70.0   70.0
# Syrah-Cabernet Franc         60.0   69.0
# Garnacha-Cariñena            57.0   57.0
# Doña Blanca                  53.0   53.0
# Cercial                      50.0   50.0
# Mavrotragano                 50.0   50.0
# Sercial                      50.0   50.0
# Pugnitello                   49.0   49.0
# Malbec-Cabernet              45.0  165.0
# Tinta del Pais               45.0   50.0
# Touriga                      45.0   46.0
# Babosa Negro                 45.0   45.0
# Cabernet Sauvignon-Barbera   45.0   45.0
# Syrah-Grenache-Viognier      45.0   45.0
# Tinta Madeira                45.0   45.0

# %% [markdown]
# # Exercici 19
#
# Mostra de cada `reviewer` utilitzant el camp `taster_name` la mitjana de puntuació que fa.

# %%
reviews.groupby("taster_name").points.mean().round(3)
# Out:
# taster_name
# Alexander Peartree    85.855
# Anna Lee C. Iijima    88.416
# Anne Krebiehl MW      90.563
# Carrie Dykes          86.396
# Christina Pickard     87.833
# Fiona Adams           86.889
# Jeff Jenssen          88.320
# Jim Gordon            88.626
# Joe Czerwinski        88.536
# Kerin O’Keefe         88.868
# Lauren Buzzeo         87.740
# Matt Kettmann         90.009
# Michael Schachner     86.907
# Mike DeSimone         89.101
# Paul Gregutt          89.083
# Roger Voss            88.708
# Sean P. Sullivan      88.756
# Susan Kostrzewa       86.609
# Virginie Boone        89.213
# Name: points, dtype: float64

# %% [markdown]
# Hi ha diferències significatives entre puntuacions dels diferents `reviewers`. Utilitza el mètode `describe()` del conjunt resultat de l'exercici.

# %% [markdown]
# # Exercici 20
#
# Quina combinació de països i varietats és més habitual?
# Crea una sèrie amb MultiIndex de parells {país, varietat} juntament amb la quantitat de reviews.
# Per exemple, un *pinot noir* produït als EUA hauria de correspondre a {"US", "Pinot Noir"}.
# Ordena el resultat en ordre descendent en funció del recompte de vins.

# %%
reviews.groupby(['country','variety']).size().sort_values(ascending=False).head(10)
# Out:
# country  variety
# US       Pinot Noir                  9885
#          Cabernet Sauvignon          7315
#          Chardonnay                  6801
# France   Bordeaux-style Red Blend    4725
# Italy    Red Blend                   3624
# US       Syrah                       3244
#          Red Blend                   2972
# France   Chardonnay                  2808
# Italy    Nebbiolo                    2736
# US       Zinfandel                   2711
# dtype: int64

# %% [markdown]
# # Exercici 21
#
# Quin és el tipus de dades del camp `points` del dataset? guarda el resultat a una variable anomenada dtype

# %%
reviews.points.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Exercici 22
#
# Converteix la columna `points` a strings. El tipus de dades string en Python és `str`.

# %%
reviews.points.astype(str)
# Out:
# dtype('O')

# %% [markdown]
# # Exercici 23
#
# Alguns valors de la columna `price`són nul·les. Quantes reviews dins del dataset no en sabem el preu?

# %%
reviews.price.isnull().value_counts()
reviews[reviews.price.isnull()].sum()
# Out:
# False    120975
# True       8996
# Name: price, dtype: int64

# %% [markdown]
# # Exercici 24
#
# Quines són les regions productores de vi més habituals?
# Crea una Sèrie que contabilitzi el nombre de vegades que apareix cada valor del camp `region_1`. En aquest camp hi falten dades. Substitueix els valors que falten per "Desconegut" i ordena de forma descendent.

# %%
reviews.region_1.fillna("Desconegut").value_counts().sort_values(ascending=False)
# Out:
# Desconegut              21247
# Napa Valley              4480
# Columbia Valley (WA)     4124
# Russian River Valley     3091
# California               2629
#                         ...
# Offida Rosso                1
# Corton Perrières            1
# Isle St. George             1
# Geelong                     1
# Paestum                     1
# Name: region_1, Length: 1230, dtype: int64
